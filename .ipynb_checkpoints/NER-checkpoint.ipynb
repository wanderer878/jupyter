# %%
import spacy
from spacy import displacy
import re
nlp = spacy.load('en_core_web_sm')

# %%
text = "Grand Theft Auto VI is an upcoming action-adventure game developed and published by Rockstar Games. It is due to be the eighth main Grand Theft Auto game, following Grand Theft Auto V (2013), and the sixteenth entry overall. Set within the fictional US state of Leonida, based on Florida, the story follows the romantic criminal duo of Jason Duval and Lucia Caminos. Players will be able to freely roam Leonida's open world, which features the Miami-inspired Vice City.Following years of speculation and anticipation, Rockstar confirmed in February 2022 that the game was in development. That September, footage from unfinished versions was leaked in what journalists described as one of the biggest leaks in the history of the video game industry. Grand Theft Auto VI was formally revealed in December 2023. Following two delays, it is scheduled to be released on 19 November 2026 for the PlayStation 5 and Xbox Series X/S."

spacy_doc = nlp(text)

spacy_doc
# Out:
# Grand Theft Auto VI is an upcoming action-adventure game developed and published by Rockstar Games. It is due to be the eighth main Grand Theft Auto game, following Grand Theft Auto V (2013), and the sixteenth entry overall. Set within the fictional US state of Leonida, based on Florida, the story follows the romantic criminal duo of Jason Duval and Lucia Caminos. Players will be able to freely roam Leonida's open world, which features the Miami-inspired Vice City.Following years of speculation and anticipation, Rockstar confirmed in February 2022 that the game was in development. That September, footage from unfinished versions was leaked in what journalists described as one of the biggest leaks in the history of the video game industry. Grand Theft Auto VI was formally revealed in December 2023. Following two delays, it is scheduled to be released on 19 November 2026 for the PlayStation 5 and Xbox Series X/S.

# %%
for word in spacy_doc.ents:
    print(word.text, '    ', word.label_)
# Out:
# Grand Theft Auto VI      ORG
# Rockstar Games      PRODUCT
# eighth      ORDINAL
# Grand Theft Auto      ORG
# Grand Theft Auto V      ORG
# 2013      DATE
# sixteenth      ORDINAL
# US      GPE
# Leonida      GPE
# Florida      GPE
# Jason Duval      PERSON
# Lucia Caminos      PERSON
# Leonida      FAC
# Miami      GPE
# Rockstar      ORG
# February 2022      DATE
# September      DATE
# Grand Theft Auto VI      ORG
# December 2023      DATE
# two      CARDINAL
# 19 November 2026      DATE
# the PlayStation 5      PRODUCT

# %%
displacy.render(spacy_doc, style = 'ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grand Theft Auto VI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is an upcoming action-adventure game developed and published by
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rockstar Games
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . It is due to be the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eighth
# ...

# %%
clean_text = re.sub('[^\w\s]','',text).lower()

spacy_doc = nlp(clean_text)

spacy_doc
# Out:
# grand theft auto vi is an upcoming actionadventure game developed and published by rockstar games it is due to be the eighth main grand theft auto game following grand theft auto v 2013 and the sixteenth entry overall set within the fictional us state of leonida based on florida the story follows the romantic criminal duo of jason duval and lucia caminos players will be able to freely roam leonidas open world which features the miamiinspired vice cityfollowing years of speculation and anticipation rockstar confirmed in february 2022 that the game was in development that september footage from unfinished versions was leaked in what journalists described as one of the biggest leaks in the history of the video game industry grand theft auto vi was formally revealed in december 2023 following two delays it is scheduled to be released on 19 november 2026 for the playstation 5 and xbox series xs

# %%
displacy.render(spacy_doc, style = 'ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">grand theft auto vi is an upcoming actionadventure game developed and published by rockstar games it is due to be the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eighth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  main grand theft auto game following grand theft auto v
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and the
# ...
