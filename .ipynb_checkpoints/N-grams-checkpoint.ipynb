# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt

nltk.download("punkt_tab")
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\usama\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
paragraph = "Mafia II is a 2010 action-adventure game developed by 2K Czech and published by 2K. It was released on 24 August 2010 for PlayStation 3, Windows, and Xbox 360. The game is a standalone sequel to 2002's Mafia, and the second installment in the Mafia series. Set within the fictional city of Empire Bay from 1945 to 1951, the story follows Vito Scaletta, a young Sicilian-American mobster and war veteran, who becomes caught in a power struggle among the city's Mafia crime families while attempting to pay back his father's debts and secure a better lifestyle."

tokens = word_tokenize(paragraph)

tokens = [t for t in tokens if t not in [",","."]]

print(tokens)
# Out:
# ['Mafia', 'II', 'is', 'a', '2010', 'action-adventure', 'game', 'developed', 'by', '2K', 'Czech', 'and', 'published', 'by', '2K', 'It', 'was', 'released', 'on', '24', 'August', '2010', 'for', 'PlayStation', '3', 'Windows', 'and', 'Xbox', '360', 'The', 'game', 'is', 'a', 'standalone', 'sequel', 'to', '2002', "'s", 'Mafia', 'and', 'the', 'second', 'installment', 'in', 'the', 'Mafia', 'series', 'Set', 'within', 'the', 'fictional', 'city', 'of', 'Empire', 'Bay', 'from', '1945', 'to', '1951', 'the', 'story', 'follows', 'Vito', 'Scaletta', 'a', 'young', 'Sicilian-American', 'mobster', 'and', 'war', 'veteran', 'who', 'becomes', 'caught', 'in', 'a', 'power', 'struggle', 'among', 'the', 'city', "'s", 'Mafia', 'crime', 'families', 'while', 'attempting', 'to', 'pay', 'back', 'his', 'father', "'s", 'debts', 'and', 'secure', 'a', 'better', 'lifestyle']

# %%
unigrams = (pd.Series(nltk.ngrams(tokens,1)).value_counts())
print(unigrams)
# Out:
# (a,)            5
# (and,)          5
# (the,)          5
# (Mafia,)        4
# (to,)           3
#                ..
# (II,)           1
# (within,)       1
# (fictional,)    1
# (of,)           1
# (lifestyle,)    1
# Name: count, Length: 73, dtype: int64

# %%
unigrams[0:10].sort_values().plot.barh(color = "lightblue", width= 0.8, figsize=(12,8))
plt.title('10 sets of unigrams')
plt.ylabel('unigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %%
bigrams = (pd.Series(nltk.ngrams(tokens,2)).value_counts())
print(bigrams)
# Out:
# (is, a)                2
# (by, 2K)               2
# ('s, Mafia)            2
# (Mafia, II)            1
# (Scaletta, a)          1
#                       ..
# (a, standalone)        1
# (game, is)             1
# (The, game)            1
# (360, The)             1
# (better, lifestyle)    1
# Name: count, Length: 95, dtype: int64

# %%
bigrams[0:10].sort_values().plot.bar(color = "lightgrey", width = 0.9, figsize =(8,12))
plt.title('10 sets of unigrams')
plt.ylabel('unigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %%
trigrams = (pd.Series(nltk.ngrams(tokens,3)).value_counts())
print(trigrams)
# Out:
# (Mafia, II, is)            1
# (the, fictional, city)     1
# (who, becomes, caught)     1
# (veteran, who, becomes)    1
# (war, veteran, who)        1
#                           ..
# (game, is, a)              1
# (The, game, is)            1
# (360, The, game)           1
# (Xbox, 360, The)           1
# (a, better, lifestyle)     1
# Name: count, Length: 97, dtype: int64

# %%
trigrams[0:10].sort_values().plot.barh(color = "green", width = 0.7, figsize = (10,8))
plt.title('10 sets of unigrams')
plt.ylabel('unigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')
